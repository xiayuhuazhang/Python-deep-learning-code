# %% [markdown]
# 1. get datasets ready

# %%
import keras

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %% [markdown]
# 2. network

# %%
from keras import models, layers
network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28, )))
network.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# 3. compile

# %%
network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 4. get image data prepaired

# %%
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28*28))
test_images = test_images.astype('float32') / 255

# %% [markdown]
# 5. get label prepaired

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# 6. results

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2542 - accuracy: 0.9265
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1039 - accuracy: 0.9691
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0689 - accuracy: 0.9798
# Epoch 4/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0495 - accuracy: 0.9850
# Epoch 5/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0375 - accuracy: 0.9886
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0669 - accuracy: 0.9811
# test_acc: 0.9811000227928162

# %%
import matplotlib.pyplot as plt 
digit = train_images[5].reshape((28, 28))
plt.imshow(digit, cmap='gray')
plt.show()
